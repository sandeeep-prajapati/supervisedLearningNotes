# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot()
# Out:
# []

# %%
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4])

# %%
x = [1,2,3,4,]
y = [11,22,33,44]

# %%
plt.plot(x,y)

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x, y)

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %%
#### start from 12 number
